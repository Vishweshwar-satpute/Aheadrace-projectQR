# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install qrcode
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#AheadraceRace Official Website QR-code
import qrcode
import matplotlib.pyplot as plt
data = "https://www.aheadrace.com/"
filename="AR1"
ARWebsite=qrcode.make(data)
image.save('ARWebsite.jpg')
plt.imshow(ARWebsite,cmap='gray')

# %%
#AheadraceRace LinkedIn QR-code
import qrcode
import matplotlib.pyplot as plt
input_data = "https://www.linkedin.com/company/aheadrace/"
V = qrcode.QRCode(version=1,box_size=10,border=5)
V.add_data(input_data)
V.make(fit=True)
img = V.make_image(fill='black', back_color='white')
img.save('ARLinkedIn.png')
plt.imshow(img,cmap='gray')
